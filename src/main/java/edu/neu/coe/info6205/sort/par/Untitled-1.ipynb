# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data: Array sizes, Cutoff values, and their corresponding average times
data = {
    'Array Size': [500000, 500000, 500000, 500000, 500000, 500000, 500000, 500000, 500000, 500000,
                   1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000,
                   2000000, 2000000, 2000000, 2000000, 2000000, 2000000, 2000000, 2000000, 2000000, 2000000,
                   4000000, 4000000, 4000000, 4000000, 4000000, 4000000, 4000000, 4000000, 4000000, 4000000,
                   8000000, 8000000, 8000000, 8000000, 8000000, 8000000, 8000000, 8000000, 8000000, 8000000],
    'Cutoff': [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000,
               10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000,
               10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000,
               10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000,
               10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000],
    'Average Time (ms)': [29, 14, 18, 14, 12, 16, 11, 14, 12, 14,
                          13, 13, 17, 17, 22, 13, 16, 12, 15, 34,
                          28, 26, 28, 24, 26, 22, 25, 25, 26, 26,
                          22, 26, 27, 26, 22, 26, 27, 25, 57, 51,
                          55, 52, 51, 57, 55, 60, 49, 47, 48, 56]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(12, 8))
for array_size in df['Array Size'].unique():
    subset = df[df['Array Size'] == array_size]
    plt.plot(subset['Cutoff'], subset['Average Time (ms)'], marker='o', label=f'Array Size: {array_size}')

plt.title('Performance with Different Cutoff Values for Various Array Sizes')
plt.xlabel('Cutoff')
plt.ylabel('Average Time (ms)')
plt.legend()
plt.grid(True)
plt.show()
